# %% [markdown]
# ### WEEK 1 TEST — Python

# %%
# Q1: Total amount of Delivered transactions
transactions = [
    {'id': 1,  'customer': 'Amit',    'city': 'Delhi',     'amount': 55500, 'status': 'Delivered', 'month': 1},
    {'id': 2,  'customer': 'Priya',   'city': 'Mumbai',    'amount': 3500,  'status': 'Delivered', 'month': 1},
    {'id': 3,  'customer': 'Rahul',   'city': 'Bangalore', 'amount': 800,   'status': 'Cancelled', 'month': 2},
    {'id': 4,  'customer': 'Sneha',   'city': 'Delhi',     'amount': 1600,  'status': 'Pending',   'month': 2},
    {'id': 5,  'customer': 'Vikram',  'city': 'Ahmedabad', 'amount': 500,   'status': 'Delivered', 'month': 3},
    {'id': 6,  'customer': 'Kavya',   'city': 'Chennai',   'amount': 4300,  'status': 'Delivered', 'month': 3},
    {'id': 7,  'customer': 'Arjun',   'city': 'Mumbai',    'amount': 1200,  'status': 'Delivered', 'month': 4},
    {'id': 8,  'customer': 'Deepika', 'city': 'Pune',      'amount': 18000, 'status': 'Cancelled', 'month': 4},
    {'id': 9,  'customer': 'Rohan',   'city': 'Kolkata',   'amount': 2500,  'status': 'Delivered', 'month': 5},
    {'id': 10, 'customer': 'Ananya',  'city': 'Delhi',     'amount': 55000, 'status': 'Delivered', 'month': 5},
    {'id': 11, 'customer': 'Amit',    'city': 'Delhi',     'amount': 3200,  'status': 'Delivered', 'month': 6},
    {'id': 12, 'customer': 'Priya',   'city': 'Mumbai',    'amount': 7800,  'status': 'Pending',   'month': 6},
]

amount = [a['amount'] for a in transactions if a['status'] == 'Delivered']
total = sum(amount)
print(total)
# Out:
# 125700

# %%
# Q2: Average amount of all transactions (round to 2 decimals)
transactions = [
    {'id': 1,  'customer': 'Amit',    'city': 'Delhi',     'amount': 55500, 'status': 'Delivered', 'month': 1},
    {'id': 2,  'customer': 'Priya',   'city': 'Mumbai',    'amount': 3500,  'status': 'Delivered', 'month': 1},
    {'id': 3,  'customer': 'Rahul',   'city': 'Bangalore', 'amount': 800,   'status': 'Cancelled', 'month': 2},
    {'id': 4,  'customer': 'Sneha',   'city': 'Delhi',     'amount': 1600,  'status': 'Pending',   'month': 2},
    {'id': 5,  'customer': 'Vikram',  'city': 'Ahmedabad', 'amount': 500,   'status': 'Delivered', 'month': 3},
    {'id': 6,  'customer': 'Kavya',   'city': 'Chennai',   'amount': 4300,  'status': 'Delivered', 'month': 3},
    {'id': 7,  'customer': 'Arjun',   'city': 'Mumbai',    'amount': 1200,  'status': 'Delivered', 'month': 4},
    {'id': 8,  'customer': 'Deepika', 'city': 'Pune',      'amount': 18000, 'status': 'Cancelled', 'month': 4},
    {'id': 9,  'customer': 'Rohan',   'city': 'Kolkata',   'amount': 2500,  'status': 'Delivered', 'month': 5},
    {'id': 10, 'customer': 'Ananya',  'city': 'Delhi',     'amount': 55000, 'status': 'Delivered', 'month': 5},
    {'id': 11, 'customer': 'Amit',    'city': 'Delhi',     'amount': 3200,  'status': 'Delivered', 'month': 6},
    {'id': 12, 'customer': 'Priya',   'city': 'Mumbai',    'amount': 7800,  'status': 'Pending',   'month': 6},
]

amount = [a['amount'] for a in transactions]
avg_amount = round(sum(amount)/len(amount), 2)
print(avg_amount)
# Out:
# 12825.0

# %%
# Q3: Count of each status — {'Delivered': ?, 'Cancelled': ?, 'Pending': ?}
transactions = [
    {'id': 1,  'customer': 'Amit',    'city': 'Delhi',     'amount': 55500, 'status': 'Delivered', 'month': 1},
    {'id': 2,  'customer': 'Priya',   'city': 'Mumbai',    'amount': 3500,  'status': 'Delivered', 'month': 1},
    {'id': 3,  'customer': 'Rahul',   'city': 'Bangalore', 'amount': 800,   'status': 'Cancelled', 'month': 2},
    {'id': 4,  'customer': 'Sneha',   'city': 'Delhi',     'amount': 1600,  'status': 'Pending',   'month': 2},
    {'id': 5,  'customer': 'Vikram',  'city': 'Ahmedabad', 'amount': 500,   'status': 'Delivered', 'month': 3},
    {'id': 6,  'customer': 'Kavya',   'city': 'Chennai',   'amount': 4300,  'status': 'Delivered', 'month': 3},
    {'id': 7,  'customer': 'Arjun',   'city': 'Mumbai',    'amount': 1200,  'status': 'Delivered', 'month': 4},
    {'id': 8,  'customer': 'Deepika', 'city': 'Pune',      'amount': 18000, 'status': 'Cancelled', 'month': 4},
    {'id': 9,  'customer': 'Rohan',   'city': 'Kolkata',   'amount': 2500,  'status': 'Delivered', 'month': 5},
    {'id': 10, 'customer': 'Ananya',  'city': 'Delhi',     'amount': 55000, 'status': 'Delivered', 'month': 5},
    {'id': 11, 'customer': 'Amit',    'city': 'Delhi',     'amount': 3200,  'status': 'Delivered', 'month': 6},
    {'id': 12, 'customer': 'Priya',   'city': 'Mumbai',    'amount': 7800,  'status': 'Pending',   'month': 6},
]

count_status = {}
for a in transactions:
    if a['status'] not in count_status:
        count_status[a['status']] = 1
    else: 
        count_status[a['status']] += 1
print(count_status)
# Out:
# {'Delivered': 8, 'Cancelled': 2, 'Pending': 2}

# %%
# Q4: City-wise total spending
transactions = [
    {'id': 1,  'customer': 'Amit',    'city': 'Delhi',     'amount': 55500, 'status': 'Delivered', 'month': 1},
    {'id': 2,  'customer': 'Priya',   'city': 'Mumbai',    'amount': 3500,  'status': 'Delivered', 'month': 1},
    {'id': 3,  'customer': 'Rahul',   'city': 'Bangalore', 'amount': 800,   'status': 'Cancelled', 'month': 2},
    {'id': 4,  'customer': 'Sneha',   'city': 'Delhi',     'amount': 1600,  'status': 'Pending',   'month': 2},
    {'id': 5,  'customer': 'Vikram',  'city': 'Ahmedabad', 'amount': 500,   'status': 'Delivered', 'month': 3},
    {'id': 6,  'customer': 'Kavya',   'city': 'Chennai',   'amount': 4300,  'status': 'Delivered', 'month': 3},
    {'id': 7,  'customer': 'Arjun',   'city': 'Mumbai',    'amount': 1200,  'status': 'Delivered', 'month': 4},
    {'id': 8,  'customer': 'Deepika', 'city': 'Pune',      'amount': 18000, 'status': 'Cancelled', 'month': 4},
    {'id': 9,  'customer': 'Rohan',   'city': 'Kolkata',   'amount': 2500,  'status': 'Delivered', 'month': 5},
    {'id': 10, 'customer': 'Ananya',  'city': 'Delhi',     'amount': 55000, 'status': 'Delivered', 'month': 5},
    {'id': 11, 'customer': 'Amit',    'city': 'Delhi',     'amount': 3200,  'status': 'Delivered', 'month': 6},
    {'id': 12, 'customer': 'Priya',   'city': 'Mumbai',    'amount': 7800,  'status': 'Pending',   'month': 6},
]

city_total_spending = {}
for a in transactions:
    if a['city'] not in city_total_spending:
        city_total_spending[a['city']] = a['amount']
    else:
        city_total_spending[a['city']] += a['amount']
print(city_total_spending)
# Out:
# {'Delhi': 115300, 'Mumbai': 12500, 'Bangalore': 800, 'Ahmedabad': 500, 'Chennai': 4300, 'Pune': 18000, 'Kolkata': 2500}

# %%
# Q5: Monthly total revenue dict — {1: total, 2: total, ...}
transactions = [
    {'id': 1,  'customer': 'Amit',    'city': 'Delhi',     'amount': 55500, 'status': 'Delivered', 'month': 1},
    {'id': 2,  'customer': 'Priya',   'city': 'Mumbai',    'amount': 3500,  'status': 'Delivered', 'month': 1},
    {'id': 3,  'customer': 'Rahul',   'city': 'Bangalore', 'amount': 800,   'status': 'Cancelled', 'month': 2},
    {'id': 4,  'customer': 'Sneha',   'city': 'Delhi',     'amount': 1600,  'status': 'Pending',   'month': 2},
    {'id': 5,  'customer': 'Vikram',  'city': 'Ahmedabad', 'amount': 500,   'status': 'Delivered', 'month': 3},
    {'id': 6,  'customer': 'Kavya',   'city': 'Chennai',   'amount': 4300,  'status': 'Delivered', 'month': 3},
    {'id': 7,  'customer': 'Arjun',   'city': 'Mumbai',    'amount': 1200,  'status': 'Delivered', 'month': 4},
    {'id': 8,  'customer': 'Deepika', 'city': 'Pune',      'amount': 18000, 'status': 'Cancelled', 'month': 4},
    {'id': 9,  'customer': 'Rohan',   'city': 'Kolkata',   'amount': 2500,  'status': 'Delivered', 'month': 5},
    {'id': 10, 'customer': 'Ananya',  'city': 'Delhi',     'amount': 55000, 'status': 'Delivered', 'month': 5},
    {'id': 11, 'customer': 'Amit',    'city': 'Delhi',     'amount': 3200,  'status': 'Delivered', 'month': 6},
    {'id': 12, 'customer': 'Priya',   'city': 'Mumbai',    'amount': 7800,  'status': 'Pending',   'month': 6},
]

monthly_revenue = {}
for a in transactions:
    if a['month'] not in monthly_revenue:
        monthly_revenue[a['month']] = a['amount']
    else:
        monthly_revenue[a['month']] += a['amount']
print(monthly_revenue)
# Out:
# {1: 59000, 2: 2400, 3: 4800, 4: 19200, 5: 57500, 6: 11000}

# %%
# Q6: Customer names where amount > 5000
transactions = [
    {'id': 1,  'customer': 'Amit',    'city': 'Delhi',     'amount': 55500, 'status': 'Delivered', 'month': 1},
    {'id': 2,  'customer': 'Priya',   'city': 'Mumbai',    'amount': 3500,  'status': 'Delivered', 'month': 1},
    {'id': 3,  'customer': 'Rahul',   'city': 'Bangalore', 'amount': 800,   'status': 'Cancelled', 'month': 2},
    {'id': 4,  'customer': 'Sneha',   'city': 'Delhi',     'amount': 1600,  'status': 'Pending',   'month': 2},
    {'id': 5,  'customer': 'Vikram',  'city': 'Ahmedabad', 'amount': 500,   'status': 'Delivered', 'month': 3},
    {'id': 6,  'customer': 'Kavya',   'city': 'Chennai',   'amount': 4300,  'status': 'Delivered', 'month': 3},
    {'id': 7,  'customer': 'Arjun',   'city': 'Mumbai',    'amount': 1200,  'status': 'Delivered', 'month': 4},
    {'id': 8,  'customer': 'Deepika', 'city': 'Pune',      'amount': 18000, 'status': 'Cancelled', 'month': 4},
    {'id': 9,  'customer': 'Rohan',   'city': 'Kolkata',   'amount': 2500,  'status': 'Delivered', 'month': 5},
    {'id': 10, 'customer': 'Ananya',  'city': 'Delhi',     'amount': 55000, 'status': 'Delivered', 'month': 5},
    {'id': 11, 'customer': 'Amit',    'city': 'Delhi',     'amount': 3200,  'status': 'Delivered', 'month': 6},
    {'id': 12, 'customer': 'Priya',   'city': 'Mumbai',    'amount': 7800,  'status': 'Pending',   'month': 6},
]

names = [a['customer'] for a in transactions if a['amount'] > 5000]
print(names)
# Out:
# ['Amit', 'Deepika', 'Ananya', 'Priya']

# %%
# Q7: Add 'category' key to each transaction: 10000+ = 'High', 1000+ = 'Medium', else 'Low'
transactions = [
    {'id': 1,  'customer': 'Amit',    'city': 'Delhi',     'amount': 55500, 'status': 'Delivered', 'month': 1},
    {'id': 2,  'customer': 'Priya',   'city': 'Mumbai',    'amount': 3500,  'status': 'Delivered', 'month': 1},
    {'id': 3,  'customer': 'Rahul',   'city': 'Bangalore', 'amount': 800,   'status': 'Cancelled', 'month': 2},
    {'id': 4,  'customer': 'Sneha',   'city': 'Delhi',     'amount': 1600,  'status': 'Pending',   'month': 2},
    {'id': 5,  'customer': 'Vikram',  'city': 'Ahmedabad', 'amount': 500,   'status': 'Delivered', 'month': 3},
    {'id': 6,  'customer': 'Kavya',   'city': 'Chennai',   'amount': 4300,  'status': 'Delivered', 'month': 3},
    {'id': 7,  'customer': 'Arjun',   'city': 'Mumbai',    'amount': 1200,  'status': 'Delivered', 'month': 4},
    {'id': 8,  'customer': 'Deepika', 'city': 'Pune',      'amount': 18000, 'status': 'Cancelled', 'month': 4},
    {'id': 9,  'customer': 'Rohan',   'city': 'Kolkata',   'amount': 2500,  'status': 'Delivered', 'month': 5},
    {'id': 10, 'customer': 'Ananya',  'city': 'Delhi',     'amount': 55000, 'status': 'Delivered', 'month': 5},
    {'id': 11, 'customer': 'Amit',    'city': 'Delhi',     'amount': 3200,  'status': 'Delivered', 'month': 6},
    {'id': 12, 'customer': 'Priya',   'city': 'Mumbai',    'amount': 7800,  'status': 'Pending',   'month': 6},
]

for a in transactions:
    if a['amount'] >= 10000:
        a['category'] = 'High'
    elif a['amount'] >= 1000:
        a['category'] = 'Medium'
    else:
        a['category'] = 'Low'
print(transactions)
# Out:
# [{'id': 1, 'customer': 'Amit', 'city': 'Delhi', 'amount': 55500, 'status': 'Delivered', 'month': 1, 'category': 'High'}, {'id': 2, 'customer': 'Priya', 'city': 'Mumbai', 'amount': 3500, 'status': 'Delivered', 'month': 1, 'category': 'Medium'}, {'id': 3, 'customer': 'Rahul', 'city': 'Bangalore', 'amount': 800, 'status': 'Cancelled', 'month': 2, 'category': 'Low'}, {'id': 4, 'customer': 'Sneha', 'city': 'Delhi', 'amount': 1600, 'status': 'Pending', 'month': 2, 'category': 'Medium'}, {'id': 5, 'customer': 'Vikram', 'city': 'Ahmedabad', 'amount': 500, 'status': 'Delivered', 'month': 3, 'category': 'Low'}, {'id': 6, 'customer': 'Kavya', 'city': 'Chennai', 'amount': 4300, 'status': 'Delivered', 'month': 3, 'category': 'Medium'}, {'id': 7, 'customer': 'Arjun', 'city': 'Mumbai', 'amount': 1200, 'status': 'Delivered', 'month': 4, 'category': 'Medium'}, {'id': 8, 'customer': 'Deepika', 'city': 'Pune', 'amount': 18000, 'status': 'Cancelled', 'month': 4, 'category': 'High'}, {'id': 9, 'customer'
# ...

# %%
# Q8: Customers who have more than 1 transaction — unka naam aur transaction count dikhao
transactions = [
    {'id': 1,  'customer': 'Amit',    'city': 'Delhi',     'amount': 55500, 'status': 'Delivered', 'month': 1},
    {'id': 2,  'customer': 'Priya',   'city': 'Mumbai',    'amount': 3500,  'status': 'Delivered', 'month': 1},
    {'id': 3,  'customer': 'Rahul',   'city': 'Bangalore', 'amount': 800,   'status': 'Cancelled', 'month': 2},
    {'id': 4,  'customer': 'Sneha',   'city': 'Delhi',     'amount': 1600,  'status': 'Pending',   'month': 2},
    {'id': 5,  'customer': 'Vikram',  'city': 'Ahmedabad', 'amount': 500,   'status': 'Delivered', 'month': 3},
    {'id': 6,  'customer': 'Kavya',   'city': 'Chennai',   'amount': 4300,  'status': 'Delivered', 'month': 3},
    {'id': 7,  'customer': 'Arjun',   'city': 'Mumbai',    'amount': 1200,  'status': 'Delivered', 'month': 4},
    {'id': 8,  'customer': 'Deepika', 'city': 'Pune',      'amount': 18000, 'status': 'Cancelled', 'month': 4},
    {'id': 9,  'customer': 'Rohan',   'city': 'Kolkata',   'amount': 2500,  'status': 'Delivered', 'month': 5},
    {'id': 10, 'customer': 'Ananya',  'city': 'Delhi',     'amount': 55000, 'status': 'Delivered', 'month': 5},
    {'id': 11, 'customer': 'Amit',    'city': 'Delhi',     'amount': 3200,  'status': 'Delivered', 'month': 6},
    {'id': 12, 'customer': 'Priya',   'city': 'Mumbai',    'amount': 7800,  'status': 'Pending',   'month': 6},
]


count = {}
for a in transactions:
    if a['customer'] not in count:
        count[a['customer']] = 1
    else:
        count[a['customer']] += 1
        
result = {a: b for a, b in count.items() if b > 1}
print(result)
# Out:
# {'Amit': 2, 'Priya': 2}

# %%
# Q9: Unique cities in data
transactions = [
    {'id': 1,  'customer': 'Amit',    'city': 'Delhi',     'amount': 55500, 'status': 'Delivered', 'month': 1},
    {'id': 2,  'customer': 'Priya',   'city': 'Mumbai',    'amount': 3500,  'status': 'Delivered', 'month': 1},
    {'id': 3,  'customer': 'Rahul',   'city': 'Bangalore', 'amount': 800,   'status': 'Cancelled', 'month': 2},
    {'id': 4,  'customer': 'Sneha',   'city': 'Delhi',     'amount': 1600,  'status': 'Pending',   'month': 2},
    {'id': 5,  'customer': 'Vikram',  'city': 'Ahmedabad', 'amount': 500,   'status': 'Delivered', 'month': 3},
    {'id': 6,  'customer': 'Kavya',   'city': 'Chennai',   'amount': 4300,  'status': 'Delivered', 'month': 3},
    {'id': 7,  'customer': 'Arjun',   'city': 'Mumbai',    'amount': 1200,  'status': 'Delivered', 'month': 4},
    {'id': 8,  'customer': 'Deepika', 'city': 'Pune',      'amount': 18000, 'status': 'Cancelled', 'month': 4},
    {'id': 9,  'customer': 'Rohan',   'city': 'Kolkata',   'amount': 2500,  'status': 'Delivered', 'month': 5},
    {'id': 10, 'customer': 'Ananya',  'city': 'Delhi',     'amount': 55000, 'status': 'Delivered', 'month': 5},
    {'id': 11, 'customer': 'Amit',    'city': 'Delhi',     'amount': 3200,  'status': 'Delivered', 'month': 6},
    {'id': 12, 'customer': 'Priya',   'city': 'Mumbai',    'amount': 7800,  'status': 'Pending',   'month': 6},
]

unique_cities = []
for a in transactions:
    if a['city'] not in unique_cities:
        unique_cities.append(a['city'])
print(unique_cities)
# Out:
# ['Delhi', 'Mumbai', 'Bangalore', 'Ahmedabad', 'Chennai', 'Pune', 'Kolkata']

# %%
# Q10: Sort transactions by amount descending — return list of (customer, amount) tuples
transactions = [
    {'id': 1,  'customer': 'Amit',    'city': 'Delhi',     'amount': 55500, 'status': 'Delivered', 'month': 1},
    {'id': 2,  'customer': 'Priya',   'city': 'Mumbai',    'amount': 3500,  'status': 'Delivered', 'month': 1},
    {'id': 3,  'customer': 'Rahul',   'city': 'Bangalore', 'amount': 800,   'status': 'Cancelled', 'month': 2},
    {'id': 4,  'customer': 'Sneha',   'city': 'Delhi',     'amount': 1600,  'status': 'Pending',   'month': 2},
    {'id': 5,  'customer': 'Vikram',  'city': 'Ahmedabad', 'amount': 500,   'status': 'Delivered', 'month': 3},
    {'id': 6,  'customer': 'Kavya',   'city': 'Chennai',   'amount': 4300,  'status': 'Delivered', 'month': 3},
    {'id': 7,  'customer': 'Arjun',   'city': 'Mumbai',    'amount': 1200,  'status': 'Delivered', 'month': 4},
    {'id': 8,  'customer': 'Deepika', 'city': 'Pune',      'amount': 18000, 'status': 'Cancelled', 'month': 4},
    {'id': 9,  'customer': 'Rohan',   'city': 'Kolkata',   'amount': 2500,  'status': 'Delivered', 'month': 5},
    {'id': 10, 'customer': 'Ananya',  'city': 'Delhi',     'amount': 55000, 'status': 'Delivered', 'month': 5},
    {'id': 11, 'customer': 'Amit',    'city': 'Delhi',     'amount': 3200,  'status': 'Delivered', 'month': 6},
    {'id': 12, 'customer': 'Priya',   'city': 'Mumbai',    'amount': 7800,  'status': 'Pending',   'month': 6},
]

x = []
for a in transactions:
    tup = (a['customer'], a['amount'])
    if tup not in x:
        x.append(tup)
print(sorted(x, key=lambda x: x[1], reverse = True))
# Out:
# [('Amit', 55500), ('Ananya', 55000), ('Deepika', 18000), ('Priya', 7800), ('Kavya', 4300), ('Priya', 3500), ('Amit', 3200), ('Rohan', 2500), ('Sneha', 1600), ('Arjun', 1200), ('Rahul', 800), ('Vikram', 500)]
